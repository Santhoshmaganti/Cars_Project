# %%
import pandas
import pandas as pd
df=pd.read_csv(r"C:\Users\91955\Santhosh\CarPrice_Assignment.csv")
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
list(df.CarName)
# Out:
# ['alfa-romero giulia',
#  'alfa-romero stelvio',
#  'alfa-romero Quadrifoglio',
#  'audi 100 ls',
#  'audi 100ls',
#  'audi fox',
#  'audi 100ls',
#  'audi 5000',
#  'audi 4000',
#  'audi 5000s (diesel)',
#  'bmw 320i',
#  'bmw 320i',
#  'bmw x1',
#  'bmw x3',
#  'bmw z4',
#  'bmw x4',
#  'bmw x5',
#  'bmw x3',
#  'chevrolet impala',
#  'chevrolet monte carlo',
#  'chevrolet vega 2300',
#  'dodge rampage',
#  'dodge challenger se',
#  'dodge d200',
#  'dodge monaco (sw)',
#  'dodge colt hardtop',
#  'dodge colt (sw)',
#  'dodge coronet custom',
#  'dodge dart custom',
#  'dodge coronet custom (sw)',
#  'honda civic',
#  'honda civic cvcc',
#  'honda civic',
#  'honda accord cvcc',
#  'honda civic cvcc',
#  'honda accord lx',
#  'honda civic 1500 gl',
#  'honda accord',
#  'honda civic 1300',
#  'honda prelude',
#  'honda accord',
#  'honda civic',
#  'honda civic (auto)',
#  'isuzu MU-X',
#  'isuzu D-Max ',
#  'isuzu D-Max V-Cross',
#  'isuzu D-Max ',
#  'jaguar xj',
#  'jaguar xf',
# ...

# %%
# df1=df.CarName=="bmw x3"
# df1

# %%
df_Q1=df[df["CarName"].isin(['bmw 320i','bmw x1','bmw x2','bmw x3','bmw x4','bmw z4','bmw x5','audi 100 ls','audi 100ls','audi fox','audi 5000','audi 4000','audi 5000s (diesel)','Nissan versa','nissan gt-r','nissan rogue','nissan latio','nissan titan','nissan leaf','nissan juke','nissan latio','nissan note','nissan clipper','nissan rogue','nissan nv200','nissan dayz','nissan fuga','nissan otti','nissan teana','nissan kicks','nissan clipper'])]
df_Q1
# Out:
#      car_ID  symboling              CarName fueltype aspiration doornumber  \
# 3         4          2          audi 100 ls      gas        std       four
# 4         5          2           audi 100ls      gas        std       four
# 5         6          2             audi fox      gas        std        two
# 6         7          1           audi 100ls      gas        std       four
# 7         8          1            audi 5000      gas        std       four
# 8         9          1            audi 4000      gas      turbo       four
# 9        10          0  audi 5000s (diesel)      gas      turbo        two
# 10       11          2             bmw 320i      gas        std        two
# 11       12          0             bmw 320i      gas        std       four
# 12       13          0               bmw x1      gas        std        two
# 13       14          0               bmw x3      gas        std       four
# ...

# %%
df_Q2=df_Q1[["CarName","price",]]
df_Q2
# Out:
#                  CarName      price
# 3            audi 100 ls  13950.000
# 4             audi 100ls  17450.000
# 5               audi fox  15250.000
# 6             audi 100ls  17710.000
# 7              audi 5000  18920.000
# 8              audi 4000  23875.000
# 9    audi 5000s (diesel)  17859.167
# 10              bmw 320i  16430.000
# 11              bmw 320i  16925.000
# 12                bmw x1  20970.000
# 13                bmw x3  21105.000
# 14                bmw z4  24565.000
# 15                bmw x4  30760.000
# 16                bmw x5  41315.000
# 17                bmw x3  36880.000
# 89          Nissan versa   5499.000
# 90           nissan gt-r   7099.000
# 91          nissan rogue   6649.000
# 92          nissan latio   6849.000
# 93          nissan titan   7349.000
# 94           nissan leaf   7299.000
# 95           nissan juke   7799.000
# 96          nissan latio   7499.000
# 97           nissan note   7999.000
# 98        nissan clipper   8249.000
# ...

# %%
df_Q3=df_Q1[["CarName","price","fuelsystem"]]
df_Q3
# Out:
#                  CarName      price fuelsystem
# 3            audi 100 ls  13950.000       mpfi
# 4             audi 100ls  17450.000       mpfi
# 5               audi fox  15250.000       mpfi
# 6             audi 100ls  17710.000       mpfi
# 7              audi 5000  18920.000       mpfi
# 8              audi 4000  23875.000       mpfi
# 9    audi 5000s (diesel)  17859.167       mpfi
# 10              bmw 320i  16430.000       mpfi
# 11              bmw 320i  16925.000       mpfi
# 12                bmw x1  20970.000       mpfi
# 13                bmw x3  21105.000       mpfi
# 14                bmw z4  24565.000       mpfi
# 15                bmw x4  30760.000       mpfi
# 16                bmw x5  41315.000       mpfi
# 17                bmw x3  36880.000       mpfi
# 89          Nissan versa   5499.000       2bbl
# 90           nissan gt-r   7099.000        idi
# 91          nissan rogue   6649.000       2bbl
# 92          nissan latio   6849.000       2bbl
# ...

# %%
df_Q4=df_Q1[["CarName","price","fuelsystem","carbody"]]
df_Q4
# Out:
#                  CarName      price fuelsystem    carbody
# 3            audi 100 ls  13950.000       mpfi      sedan
# 4             audi 100ls  17450.000       mpfi      sedan
# 5               audi fox  15250.000       mpfi      sedan
# 6             audi 100ls  17710.000       mpfi      sedan
# 7              audi 5000  18920.000       mpfi      wagon
# 8              audi 4000  23875.000       mpfi      sedan
# 9    audi 5000s (diesel)  17859.167       mpfi  hatchback
# 10              bmw 320i  16430.000       mpfi      sedan
# 11              bmw 320i  16925.000       mpfi      sedan
# 12                bmw x1  20970.000       mpfi      sedan
# 13                bmw x3  21105.000       mpfi      sedan
# 14                bmw z4  24565.000       mpfi      sedan
# 15                bmw x4  30760.000       mpfi      sedan
# 16                bmw x5  41315.000       mpfi      sedan
# 17                bmw x3  36880.000       mpfi      sedan
# ...

# %%
df_Q5=df_Q1[["CarName","price","fuelsystem","carbody","compressionratio","horsepower","peakrpm",
             "citympg","highwaympg"]]
df_Q5
# Out:
#                  CarName      price fuelsystem    carbody  compressionratio  \
# 3            audi 100 ls  13950.000       mpfi      sedan              10.0
# 4             audi 100ls  17450.000       mpfi      sedan               8.0
# 5               audi fox  15250.000       mpfi      sedan               8.5
# 6             audi 100ls  17710.000       mpfi      sedan               8.5
# 7              audi 5000  18920.000       mpfi      wagon               8.5
# 8              audi 4000  23875.000       mpfi      sedan               8.3
# 9    audi 5000s (diesel)  17859.167       mpfi  hatchback               7.0
# 10              bmw 320i  16430.000       mpfi      sedan               8.8
# 11              bmw 320i  16925.000       mpfi      sedan               8.8
# 12                bmw x1  20970.000       mpfi      sedan               9.0
# 13                bmw x3  21105.000       mpfi      sedan               9.0
# ...

# %%
df_Q6=df_Q1[["CarName","price","fuelsystem","carbody","compressionratio","horsepower","peakrpm",
             "citympg","highwaympg","enginetype","cylindernumber","enginesize","boreratio","stroke"]]
df_Q6
# Out:
#                  CarName      price fuelsystem    carbody  compressionratio  \
# 3            audi 100 ls  13950.000       mpfi      sedan              10.0
# 4             audi 100ls  17450.000       mpfi      sedan               8.0
# 5               audi fox  15250.000       mpfi      sedan               8.5
# 6             audi 100ls  17710.000       mpfi      sedan               8.5
# 7              audi 5000  18920.000       mpfi      wagon               8.5
# 8              audi 4000  23875.000       mpfi      sedan               8.3
# 9    audi 5000s (diesel)  17859.167       mpfi  hatchback               7.0
# 10              bmw 320i  16430.000       mpfi      sedan               8.8
# 11              bmw 320i  16925.000       mpfi      sedan               8.8
# 12                bmw x1  20970.000       mpfi      sedan               9.0
# 13                bmw x3  21105.000       mpfi      sedan               9.0
# ...

# %%
df_Q7=df_Q1[df_Q1[['cylindernumber','enginetype']].isin(['one','two','three','four','five','six','ohc']).all(axis=1)]
df_Q7
# Out:
#      car_ID  symboling              CarName fueltype aspiration doornumber  \
# 3         4          2          audi 100 ls      gas        std       four
# 4         5          2           audi 100ls      gas        std       four
# 5         6          2             audi fox      gas        std        two
# 6         7          1           audi 100ls      gas        std       four
# 7         8          1            audi 5000      gas        std       four
# 8         9          1            audi 4000      gas      turbo       four
# 9        10          0  audi 5000s (diesel)      gas      turbo        two
# 10       11          2             bmw 320i      gas        std        two
# 11       12          0             bmw 320i      gas        std       four
# 12       13          0               bmw x1      gas        std        two
# 13       14          0               bmw x3      gas        std       four
# ...

# %%
df_Q7.cylindernumber.unique()
# Out:
# array(['four', 'five', 'six'], dtype=object)

# %%
df_Q7.enginetype.unique()
# Out:
# array(['ohc'], dtype=object)

# %%
df_Q7[['enginetype','cylindernumber','enginesize','fuelsystem','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg','price']]
# Out:
#     enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# 3          ohc           four         109       mpfi       3.19    3.40
# 4          ohc           five         136       mpfi       3.19    3.40
# 5          ohc           five         136       mpfi       3.19    3.40
# 6          ohc           five         136       mpfi       3.19    3.40
# 7          ohc           five         136       mpfi       3.19    3.40
# 8          ohc           five         131       mpfi       3.13    3.40
# 9          ohc           five         131       mpfi       3.13    3.40
# 10         ohc           four         108       mpfi       3.50    2.80
# 11         ohc           four         108       mpfi       3.50    2.80
# 12         ohc            six         164       mpfi       3.31    3.19
# 13         ohc            six         164       mpfi       3.31    3.19
# 14         ohc            six         164       mpfi       3.31    3.19
# ...

# %%
df_Q7_one=df_Q1[(df_Q1['enginetype']=='ohc') & (df_Q1['cylindernumber']=='one')]
df_Q7_one
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, CarName, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
df_Q7_one[['enginetype','cylindernumber','enginesize','fuelsystem','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg','price']]
# Out:
# Empty DataFrame
# Columns: [enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []

# %%
df_Q1[['cylindernumber','enginesize','fuelsystem','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg','price']]
# Out:
#     cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# 3             four         109       mpfi       3.19    3.40
# 4             five         136       mpfi       3.19    3.40
# 5             five         136       mpfi       3.19    3.40
# 6             five         136       mpfi       3.19    3.40
# 7             five         136       mpfi       3.19    3.40
# 8             five         131       mpfi       3.13    3.40
# 9             five         131       mpfi       3.13    3.40
# 10            four         108       mpfi       3.50    2.80
# 11            four         108       mpfi       3.50    2.80
# 12             six         164       mpfi       3.31    3.19
# 13             six         164       mpfi       3.31    3.19
# 14             six         164       mpfi       3.31    3.19
# 15             six         209       mpfi       3.62    3.39
# 16             six         209       mpfi       3.62    3.39
# ...

# %%
df_Q9=df_Q1[df_Q1['cylindernumber'].isin(['one','two','three'])]
df_Q9
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, CarName, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
df_Q9[['cylindernumber','price']]
# Out:
# Empty DataFrame
# Columns: [cylindernumber, price]
# Index: []

# %%
df_Q1[['fuelsystem','boreratio','stroke','compressionratio']]
# Out:
#     fuelsystem  boreratio  stroke  compressionratio
# 3         mpfi       3.19    3.40              10.0
# 4         mpfi       3.19    3.40               8.0
# 5         mpfi       3.19    3.40               8.5
# 6         mpfi       3.19    3.40               8.5
# 7         mpfi       3.19    3.40               8.5
# 8         mpfi       3.13    3.40               8.3
# 9         mpfi       3.13    3.40               7.0
# 10        mpfi       3.50    2.80               8.8
# 11        mpfi       3.50    2.80               8.8
# 12        mpfi       3.31    3.19               9.0
# 13        mpfi       3.31    3.19               9.0
# 14        mpfi       3.31    3.19               9.0
# 15        mpfi       3.62    3.39               8.0
# 16        mpfi       3.62    3.39               8.0
# 17        mpfi       3.62    3.39               8.0
# 89        2bbl       3.15    3.29               9.4
# 90         idi       2.99    3.47              21.9
# ...

# %%
df_Q10=df_Q1[df_Q1['cylindernumber'].isin(['one','two','three','four'])]
df_Q10
# Out:
#      car_ID  symboling         CarName fueltype aspiration doornumber  \
# 3         4          2     audi 100 ls      gas        std       four
# 10       11          2        bmw 320i      gas        std        two
# 11       12          0        bmw 320i      gas        std       four
# 89       90          1    Nissan versa      gas        std        two
# 90       91          1     nissan gt-r   diesel        std        two
# 91       92          1    nissan rogue      gas        std        two
# 92       93          1    nissan latio      gas        std       four
# 93       94          1    nissan titan      gas        std       four
# 94       95          1     nissan leaf      gas        std        two
# 95       96          1     nissan juke      gas        std        two
# 96       97          1    nissan latio      gas        std       four
# 97       98          1     nissan note      gas        std       four
# ...

# %%
df_Q10[['cylindernumber','horsepower','peakrpm','citympg','highwaympg','price']]
df_Q10
# Out:
#      car_ID  symboling         CarName fueltype aspiration doornumber  \
# 3         4          2     audi 100 ls      gas        std       four
# 10       11          2        bmw 320i      gas        std        two
# 11       12          0        bmw 320i      gas        std       four
# 89       90          1    Nissan versa      gas        std        two
# 90       91          1     nissan gt-r   diesel        std        two
# 91       92          1    nissan rogue      gas        std        two
# 92       93          1    nissan latio      gas        std       four
# 93       94          1    nissan titan      gas        std       four
# 94       95          1     nissan leaf      gas        std        two
# 95       96          1     nissan juke      gas        std        two
# 96       97          1    nissan latio      gas        std       four
# 97       98          1     nissan note      gas        std       four
# ...
